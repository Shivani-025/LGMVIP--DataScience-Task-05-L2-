# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn import tree

# %%
define=pd.read_csv('C:/Users/shivani/Downloads/iris.csv')
define
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
define.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
features = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']


x = define.loc[:, features].values

# %%
y=define.Species

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, random_state=0)

classification = DecisionTreeClassifier(max_depth = 2,random_state = 0)

classification.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
classification.predict(x_test[0:1])
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
from sklearn import metrics
import seaborn as sns

# %%
score = classification.score(x_test, y_test)
print(score)
# Out:
# 0.8947368421052632

# %%
print(metrics.classification_report(y_test,clf.predict(x_test)))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.83      0.94      0.88        16
#  Iris-virginica       0.86      0.67      0.75         9
#
#        accuracy                           0.89        38
#       macro avg       0.90      0.87      0.88        38
#    weighted avg       0.90      0.89      0.89        38

# %%
CMtrx = metrics.confusion_matrix(y_test, clf.predict(x_test))

plt.figure(figsize=(7,7))
sns.heatmap(CMtrx, annot=True,
            fmt=".0f",
            linewidths=.5,
            square = True,
            cmap = 'Blues');
plt.ylabel('Actual label', fontsize = 17);
plt.xlabel('Predicted label', fontsize = 17);
plt.title('Accuracy Score: {}'.format(score), size = 17);
plt.tick_params(labelsize= 15)

# %%
max_depth_range = list(range(1, 6))


accuracy = []

for depth in max_depth_range:
    
    classification = DecisionTreeClassifier(max_depth = depth, 
                             random_state = 0)
    classification.fit(x_train, y_train)

    score = classification.score(x_test, y_test)
    accuracy.append(score)

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (10,7));

ax.plot(max_depth_range,
        accuracy,
        lw=2,
        color='k')

ax.set_xlim([1, 5])
ax.set_ylim([.50, 1.00])
ax.grid(True,
        axis = 'both',
        zorder = 0,
        linestyle = ':',
        color = 'k')


ax.tick_params(labelsize = 18)
ax.set_xticks([1,2,3,4,5])
ax.set_xlabel('max_depth', fontsize = 24)
ax.set_ylabel('Accuracy', fontsize = 24)
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (7,4), dpi = 150)

tree.plot_tree(classification);

# %%
fn = ['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn = ['setosa', 'versicolor', 'virginica']

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (7,4), dpi = 300)

tree.plot_tree(classification,
               feature_names = fn, 
               class_names=cn,
               filled = True);
